# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# %matplotlib inline

# %%
dset = pd.read_csv("../dataset/spam.csv",encoding = "latin-1")
dset.head(8)
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
# 5  spam  FreeMsg Hey there darling it's been 3 week's n...        NaN
# 6   ham  Even my brother is not like to speak with me. ...        NaN
# 7   ham  As per your request 'Melle Melle (Oru Minnamin...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# 5        NaN        NaN
# 6        NaN        NaN
# 7        NaN        NaN

# %%
dset.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis = 1, inplace = True)
dset.rename(columns = {'v1': 'Class', 'v2': 'Message'}, inplace = True)
dset.head()
# Out:
#   Class                                            Message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
dset.loc[dset['Class']=="ham","Class"] = 0

# %%
dset.loc[dset['Class']=="spam","Class"] = 1

# %%
spam_words = ' '.join(list(dset[dset['Class'] == 1]['Message']))
spam_wc = WordCloud(width = 512,height = 512).generate(spam_words)
plt.figure(figsize = (10, 8), facecolor = 'k')
plt.imshow(spam_wc)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()

# %%
ham_words = ' '.join(list(dset[dset['Class'] == 0]['Message']))
ham_wc = WordCloud(width = 512,height = 512).generate(ham_words)
plt.figure(figsize = (10, 8), facecolor = 'k')
plt.imshow(ham_wc)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()

# %%
#clean message from punctuations
def cleanMessage(message):
    nonPunc = [char for char in message if char not in string.punctuation]
    nonPunc = "".join(nonPunc)
    return nonPunc

# %%
dset['Message'] = dset['Message'].apply(cleanMessage)

# %%
dset.head(8)
# Out:
#   Class                                            Message
# 0     0  Go until jurong point crazy Available only in ...
# 1     0                            Ok lar Joking wif u oni
# 2     1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3     0        U dun say so early hor U c already then say
# 4     0  Nah I dont think he goes to usf he lives aroun...
# 5     1  FreeMsg Hey there darling its been 3 weeks now...
# 6     0  Even my brother is not like to speak with me T...
# 7     0  As per your request Melle Melle Oru Minnaminun...

# %%
CV = CountVectorizer(stop_words="english")

# %%
x = dset['Message'].values
y = dset['Class'].values

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
xtrain_CV = CV.fit_transform(xtrain)

# %%
feat_names = CV.get_feature_names()

doc_names = ['Doc{:d}'.format(idx) for idx, _ in enumerate(xtrain_CV)]
df = pd.DataFrame(data=xtrain_CV.toarray(), index=doc_names,columns=feat_names)
df
# Out:
#          008704050406  0089my  01223585334  0125698789  02  020603  0207  \
# Doc0                0       0            0           0   0       0     0
# Doc1                0       0            0           0   0       0     0
# Doc2                0       0            0           0   0       0     0
# Doc3                0       0            0           0   0       0     0
# Doc4                0       0            0           0   0       0     0
# Doc5                0       0            0           0   0       0     0
# Doc6                0       0            0           0   0       0     0
# Doc7                0       0            0           0   0       0     0
# Doc8                0       0            0           0   0       0     0
# Doc9                0       0            0           0   0       0     0
# Doc10               0       0            0           0   0       0     0
# Doc11               0       0            0           0   0       0     0
# Doc12               0       0            0           0   0       0     0
# Doc13               0       0            0           0   0       0     0
# Doc14               0       0            0           0   0       0     0
# Doc15               0       0            0           0   0       0     0
# Doc16               0       0            0           0   0       0     0
# Doc17               0       0            0           0   0       0     0
# Doc18               0       0            0           0   0       0     0
# Doc19               0       0            0           0   0       0     0
# Doc20               0       0            0           0   0       0     0
# Doc21               0       0            0           0   0       0     0
# Doc22               0       0            0           0   0       0     0
# Doc23               0       0            0           0   0       0     0
# Doc24               0       0            0           0   0       0     0
# Doc25               0       0            0           0   0       0     0

# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
xtest_CV = CV.transform(xtest)
y_pred = NB.predict(xtest_CV)
accuracyScore = accuracy_score(ytest,y_pred)*100
print("Prediction Accuracy :",accuracyScore)
# Out:
# Prediction Accuracy : 98.47533632286995

# %%
msg = input("Enter Message: ")
msgInput = CV.transform([msg])
predict = NB.predict(msgInput)
if(predict[0]==1):
    print("SPAM")
else:
    print("HAM")
# Out:
# Enter Message: free entry
# SPAM

# %%
import pickle
pickle.dump(NB, open('model.pkl', 'wb'))

# %%
import requests,json
url = 'http://127.0.0.1:5000/api'
msgg = "free entry"
# msgg = CV.transform([msgg])
# print(type(msgg))
data = {"text": msgg}

# %%
data = json.dumps(data)

# %%
data
# Out:
# '{"text": "free entry"}'

# %%
from scipy import sparse

a = sparse.csr_matrix(data["text"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\scipy\sparse\base.py in asformat(self, format, copy)
#     326             try:
# --> 327                 return convert_method(copy=copy)
#     328             except TypeError:
#
# ~\Anaconda3\lib\site-packages\scipy\sparse\coo.py in tocsr(self, copy)
#     399             indices = np.empty_like(col, dtype=idx_dtype)
# --> 400             data = np.empty_like(self.data, dtype=upcast(self.dtype))
#     401
#
# ~\Anaconda3\lib\site-packages\scipy\sparse\sputils.py in upcast(*args)
#      51
# ---> 52     raise TypeError('no supported conversion for types: %r' % (args,))
#      53
#
# TypeError: no supported conversion for types: (dtype('<U27'),)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-aebe49bfa4e3> in <module>
#       1 from scipy import sparse
#       2
# ----> 3 a = sparse.csr_matrix(data["text"])
#
# ~\Anaconda3\lib\site-packages\scipy\sparse\compressed.py in __init__(self, arg1, shape, dtype, copy)
#      81                                  "".format(self.format))
#      82             from .coo import coo_matrix
# ---> 83             self._set_self(self.__class__(coo_matrix(arg1, dtype=dtype)))
#      84
#      85         # Read matrix dimensions given, if any
#
# ~\Anaconda3\lib\site-packages\scipy\sparse\compressed.py in __init__(self, arg1, shape, dtype, copy)
#      30                 arg1 = arg1.copy()
#      31             else:
# ---> 32                 arg1 = arg1.asformat(self.format)
#      33             self._set_self(arg1)
#      34
#
# ~\Anaconda3\lib\site-packages\scipy\sparse\base.py in asformat(self, format, copy)
#     327                 return convert_method(copy=copy)
#     328             except TypeError:
# --> 329                 return convert_method()
#     330
#     331     ###################################################################
#
# ~\Anaconda3\lib\site-packages\scipy\sparse\coo.py in tocsr(self, copy)
#     398             indptr = np.empty(M + 1, dtype=idx_dtype)
#     399             indices = np.empty_like(col, dtype=idx_dtype)
# --> 400             data = np.empty_like(self.data, dtype=upcast(self.dtype))
#     401
#     402             coo_tocsr(M, N, self.nnz, row, col, self.data,
#
# ~\Anaconda3\lib\site-packages\scipy\sparse\sputils.py in upcast(*args)
#      50             return t
#      51
# ---> 52     raise TypeError('no supported conversion for types: %r' % (args,))
#      53
#      54
#
# TypeError: no supported conversion for types: (dtype('<U27'),)

# %%
pickle.dump(CV, open('vectorizer.pkl', 'wb'))

# %%
header = {
    'Content-type': 'application/json',
}
send = requests.post(url,json.dumps(data))

# %%
send
# Out:
# <Response [500]>
